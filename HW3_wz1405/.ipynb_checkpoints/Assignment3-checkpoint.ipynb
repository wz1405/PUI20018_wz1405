# %%
import os
import io
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import json
from pandas.io.json import json_normalize
import sys

puidata= os.getenv("PUIDATA")
if puidata is None:
    os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")
    
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
print (url)
print data
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9
# {"Siri":{"ServiceDelivery":{"ResponseTimestamp":"2018-09-25T17:15:45.685-04:00","VehicleMonitoringDelivery":[{"VehicleActivity":[{"MonitoredVehicleJourney":{"LineRef":"MTA NYCT_B9","DirectionRef":"1","FramedVehicleJourneyRef":{"DataFrameRef":"2018-09-25","DatedVehicleJourneyRef":"MTA NYCT_JG_D8-Weekday-SDon-102800_B9_30"},"JourneyPatternRef":"MTA_B9O0113","PublishedLineName":"B9","OperatorRef":"MTA NYCT","OriginRef":"MTA_300969","DestinationRef":"MTA_901297","DestinationName":"BAY RDGE SHORE RD via AVENUE M via 60 ST","SituationRef":[],"Monitored":true,"VehicleLocation":{"Longitude":-73.93567,"Latitude":40.621491},"Bearing":138.15794,"ProgressRate":"normalProgress","BlockRef":"MTA NYCT_JG_D8-Weekday-SDon_E_JG_24840_B9-19","VehicleRef":"MTA NYCT_800","MonitoredCall":{"ExpectedArrivalTime":"2018-09-25T17:15:46.685-04:00","ExpectedDepartureTime":"2018-09-25T17:15:46.685-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":1920.25}},"StopPointRef":"MTA_303223","VisitNumber":1,"StopPointName":"FLATBUSH AV/FLATLANDS AV"},"OnwardCalls":{"OnwardCall":[{"ExpectedArrivalTime":"2018-09-25T17:15:45.685-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":1920.25}},"StopPointRef":"MTA_303223","StopPointName":"FLATBUSH AV/FLATLANDS AV"},{"ExpectedArrivalTime":"2018-09-25T17:17:41.178-04:00","Extensions":{"Distances":{"PresentableDistance":"1 stop away","DistanceFromCall":262.9,"StopsFromCall":1,"CallDistanceAlongRoute":2183.15}},"StopPointRef":"MTA_300971","StopPointName":"AV L/FLATBUSH AV"},{"ExpectedArrivalTime":"2018-09-25T17:18:51.978-04:00","Extensions":{"Distances":{"PresentableDistance":"2 stops away","DistanceFromCall":505.39,"StopsFromCall":2,"CallDistanceAlongRoute":2425.64}},"StopPointRef":"MTA_306827","StopPointName":"AV L/E 36 ST"},{"ExpectedArrivalTime":"2018-09-25T17:19:52.163-04:00","Extensions":{"Distances":{"PresentableDistance":"3 stops away","DistanceFromCall":743.2,"StopsFromCall":3,"CallDistanceAlongRoute":2663.45}},"StopPointRef":"MTA_300974","StopPointName":"AV L/NEW YORK AV"},{"ExpectedArrivalTime":"2018-09-25T17:21:17.218-04:00","Extensions":{"Distances":{"PresentableDistance":"0.6 miles away","DistanceFromCall":976.98,"StopsFromCall":4,"CallDistanceAlongRoute":2897.24}},"StopPointRef":"MTA_300975","StopPointName":"AV L/NOSTRAND AV"},{"ExpectedArrivalTime":"2018-09-25T17:22:16.862-04:00","Extensions":{"Distances":{"PresentableDistance":"0.7 miles away","DistanceFromCall":1159.25,"StopsFromCall":5,"CallDistanceAlongRoute":3079.5}},"StopPointRef":"MTA_306828","StopPointName":"AV L/E 28 ST"},{"ExpectedArrivalTime":"2018-09-25T17:23:25.224-04:00","Extensions":{"Distances":{"PresentableDistance":"0.9 miles away","DistanceFromCall":1390.35,"StopsFromCall":6,"CallDistanceAlongRoute":3310.6}},"StopPointRef":"MTA_300977","StopPointName":"AV L/BEDFORD AV"},{"ExpectedArrivalTime":"2018-09-25T17:24:18.695-04:00","Extensions":{"Distances":{"PresentableDistance":"1.0 miles away","DistanceFromCall":1554.75,"StopsFromCall":7,"CallDistanceAlongRoute":3475.0}},"StopPointRef":"MTA_300978","StopPointName":"AV L/E 23 ST"},{"ExpectedArrivalTime":"2018-09-25T17:25:39.281-04:00","Extensions":{"Distances":{"PresentableDistance":"1.1 miles away","DistanceFromCall":1808.1,"StopsFromCall":8,"CallDistanceAlongRoute":3728.35}},"StopPointRef":"MTA_300980","StopPointName":"OCEAN AV/AV L"},{"ExpectedArrivalTime":"2018-09-25T17:27:04.481-04:00","Extensions":{"Distances":{"PresentableDistance":"1.3 miles away","DistanceFromCall":2077.85,"StopsFromCall":9,"CallDistanceAlongRoute":3998.1}},"StopPointRef":"MTA_300981","StopPointName":"AV M/OCEAN AV"},{"ExpectedArrivalTime":"2018-09-25T17:28:28.990-04:00","Extensions":{"Distances":{"PresentableDistance":"1.4 miles away","DistanceFromCall":2253.91,"StopsFromCall":10,"CallDistanceAlongRoute":4174.17}},"StopPointRef":"MTA_300982","StopPointName":"AV M ...

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?" + "&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae" + "&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
print (url)
print data
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9
# {"Siri":{"ServiceDelivery":{"ResponseTimestamp":"2018-09-25T17:15:47.203-04:00","VehicleMonitoringDelivery":[{"VehicleActivity":[{"MonitoredVehicleJourney":{"LineRef":"MTA NYCT_B9","DirectionRef":"1","FramedVehicleJourneyRef":{"DataFrameRef":"2018-09-25","DatedVehicleJourneyRef":"MTA NYCT_JG_D8-Weekday-SDon-102800_B9_30"},"JourneyPatternRef":"MTA_B9O0113","PublishedLineName":"B9","OperatorRef":"MTA NYCT","OriginRef":"MTA_300969","DestinationRef":"MTA_901297","DestinationName":"BAY RDGE SHORE RD via AVENUE M via 60 ST","SituationRef":[],"Monitored":true,"VehicleLocation":{"Longitude":-73.93567,"Latitude":40.621491},"Bearing":138.15794,"ProgressRate":"normalProgress","BlockRef":"MTA NYCT_JG_D8-Weekday-SDon_E_JG_24840_B9-19","VehicleRef":"MTA NYCT_800","MonitoredCall":{"ExpectedArrivalTime":"2018-09-25T17:15:48.203-04:00","ExpectedDepartureTime":"2018-09-25T17:15:48.203-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":1920.25}},"StopPointRef":"MTA_303223","VisitNumber":1,"StopPointName":"FLATBUSH AV/FLATLANDS AV"},"OnwardCalls":{"OnwardCall":[{"ExpectedArrivalTime":"2018-09-25T17:15:47.203-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":1920.25}},"StopPointRef":"MTA_303223","StopPointName":"FLATBUSH AV/FLATLANDS AV"},{"ExpectedArrivalTime":"2018-09-25T17:17:41.178-04:00","Extensions":{"Distances":{"PresentableDistance":"1 stop away","DistanceFromCall":262.9,"StopsFromCall":1,"CallDistanceAlongRoute":2183.15}},"StopPointRef":"MTA_300971","StopPointName":"AV L/FLATBUSH AV"},{"ExpectedArrivalTime":"2018-09-25T17:18:51.978-04:00","Extensions":{"Distances":{"PresentableDistance":"2 stops away","DistanceFromCall":505.39,"StopsFromCall":2,"CallDistanceAlongRoute":2425.64}},"StopPointRef":"MTA_306827","StopPointName":"AV L/E 36 ST"},{"ExpectedArrivalTime":"2018-09-25T17:19:52.163-04:00","Extensions":{"Distances":{"PresentableDistance":"3 stops away","DistanceFromCall":743.2,"StopsFromCall":3,"CallDistanceAlongRoute":2663.45}},"StopPointRef":"MTA_300974","StopPointName":"AV L/NEW YORK AV"},{"ExpectedArrivalTime":"2018-09-25T17:21:17.218-04:00","Extensions":{"Distances":{"PresentableDistance":"0.6 miles away","DistanceFromCall":976.98,"StopsFromCall":4,"CallDistanceAlongRoute":2897.24}},"StopPointRef":"MTA_300975","StopPointName":"AV L/NOSTRAND AV"},{"ExpectedArrivalTime":"2018-09-25T17:22:16.862-04:00","Extensions":{"Distances":{"PresentableDistance":"0.7 miles away","DistanceFromCall":1159.25,"StopsFromCall":5,"CallDistanceAlongRoute":3079.5}},"StopPointRef":"MTA_306828","StopPointName":"AV L/E 28 ST"},{"ExpectedArrivalTime":"2018-09-25T17:23:25.224-04:00","Extensions":{"Distances":{"PresentableDistance":"0.9 miles away","DistanceFromCall":1390.35,"StopsFromCall":6,"CallDistanceAlongRoute":3310.6}},"StopPointRef":"MTA_300977","StopPointName":"AV L/BEDFORD AV"},{"ExpectedArrivalTime":"2018-09-25T17:24:18.695-04:00","Extensions":{"Distances":{"PresentableDistance":"1.0 miles away","DistanceFromCall":1554.75,"StopsFromCall":7,"CallDistanceAlongRoute":3475.0}},"StopPointRef":"MTA_300978","StopPointName":"AV L/E 23 ST"},{"ExpectedArrivalTime":"2018-09-25T17:25:39.281-04:00","Extensions":{"Distances":{"PresentableDistance":"1.1 miles away","DistanceFromCall":1808.1,"StopsFromCall":8,"CallDistanceAlongRoute":3728.35}},"StopPointRef":"MTA_300980","StopPointName":"OCEAN AV/AV L"},{"ExpectedArrivalTime":"2018-09-25T17:27:04.481-04:00","Extensions":{"Distances":{"PresentableDistance":"1.3 miles away","DistanceFromCall":2077.85,"StopsFromCall":9,"CallDistanceAlongRoute":3998.1}},"StopPointRef":"MTA_300981","StopPointName":"AV M/OCEAN AV"},{"ExpectedArrivalTime":"2018-09-25T17:28:28.990-04:00","Extensions":{"Distances":{"PresentableDistance":"1.4 miles away","DistanceFromCall":2253.91,"StopsFromCall":10,"CallDistanceAlongRoute":4174.17}},"StopPointRef":"MTA_300982","StopPointName":"AV M ...

# %%
#https://docs.python-guide.org/scenarios/json/
parsed_data = json.loads(data)
print type(parsed_data)
# Out:
# <type 'dict'>

# %%
BusLine = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
print BusLine
# Out:
# B9

# %%
Longitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["VehicleLocation"]["Longitude"])
print Longitude
# Out:
# -73.93567

# %%
Latitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"])
print Latitude
# Out:
# 40.621491

# %%
Latitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][1]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"])
print Latitude
# Out:
# 40.617601

# %%
print "Bus Line : %s" %  (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
# Out:
# Bus Line : B9

# %%
#https://www.tutorialspoint.com/python/dictionary_len.htm
BusNumbers = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"])
print "Number of Active Buses : %d" % len (BusNumbers)
# Out:
# Number of Active Buses : 19

# %%
BusNum = len (BusNumbers)
print BusNum
# Out:
# 19

# %%
for i in range(BusNum):
    print (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"])
# Out:
# {u'Latitude': 40.611417, u'Longitude': -73.924157}
# {u'Latitude': 40.617544, u'Longitude': -73.964048}
# {u'Latitude': 40.635642, u'Longitude': -74.009797}
# {u'Latitude': 40.615474, u'Longitude': -73.976426}
# {u'Latitude': 40.640789, u'Longitude': -74.018362}
# {u'Latitude': 40.622012, u'Longitude': -73.945615}
# {u'Latitude': 40.636419, u'Longitude': -74.028304}
# {u'Latitude': 40.620906, u'Longitude': -73.985418}
# {u'Latitude': 40.621645, u'Longitude': -73.935843}
# {u'Latitude': 40.630874, u'Longitude': -74.001904}
# {u'Latitude': 40.620987, u'Longitude': -73.954872}
# {u'Latitude': 40.628207, u'Longitude': -73.997482}
# {u'Latitude': 40.618488, u'Longitude': -73.955526}
# {u'Latitude': 40.614465, u'Longitude': -73.969903}
# {u'Latitude': 40.636646, u'Longitude': -74.011464}
# {u'Latitude': 40.610114, u'Longitude': -73.923013}
# {u'Latitude': 40.608571, u'Longitude': -73.920952}

# %%
A = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]
A
# Out:
# {u'Latitude': 40.608571, u'Longitude': -73.920952}

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?" + "&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae" + "&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
parsed_data = json.loads(data)
print "Bus Line : %s" %  (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
BusNumbers = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"])
print "Number of Active Buses : %d" % len (BusNumbers)
BusNum = len (BusNumbers)
for i in range(BusNum):
    B = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"]
    C = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]["Longitude"]
    print ("Bus %s" % i + " is at Latitude %s" % B + " Longitude %s" % C )
# Out:
# Bus Line : B9
# Number of Active Buses : 17
# Bus 0 is at Latitude 40.611417 Longitude -73.924157
# Bus 1 is at Latitude 40.621025 Longitude -73.935168
# Bus 2 is at Latitude 40.63661 Longitude -74.028919
# Bus 3 is at Latitude 40.635627 Longitude -74.009772
# Bus 4 is at Latitude 40.618317 Longitude -73.957037
# Bus 5 is at Latitude 40.631433 Longitude -74.002826
# Bus 6 is at Latitude 40.616474 Longitude -73.97807
# Bus 7 is at Latitude 40.614314 Longitude -73.971302
# Bus 8 is at Latitude 40.627835 Longitude -73.996843
# Bus 9 is at Latitude 40.640117 Longitude -74.017244
# Bus 10 is at Latitude 40.617582 Longitude -73.96371
# Bus 11 is at Latitude 40.620987 Longitude -73.954872
# Bus 12 is at Latitude 40.621932 Longitude -73.946309
# Bus 13 is at Latitude 40.620386 Longitude -73.984556
# Bus 14 is at Latitude 40.636646 Longitude -74.011464
# Bus 15 is at Latitude 40.610137 Longitude -73.923037
# Bus 16 is at Latitude 40.608571 Longitude -73.920952

# %%
7f84d332-2f33-49c1-94f5-fdc4cf2231ae

# %%
# When the OnwardCalls field is empty, you must output “N/A” as values for both the “Stop Name” and “Stop Status” fields.

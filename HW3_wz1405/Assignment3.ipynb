# %%
import os
import io
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import json
from pandas.io.json import json_normalize
import sys

puidata= os.getenv("PUIDATA")
if puidata is None:
    os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")
    
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B46" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
print (url)
print data
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B46
# ...

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?" + "&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae" + "&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
print (url)
print data
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B9
# ...

# %%
#https://docs.python-guide.org/scenarios/json/
parsed_data = json.loads(data)
print type(parsed_data)
# Out:
# <type 'dict'>

# %%
BusLine = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
print BusLine
# Out:
# B9

# %%
Longitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["VehicleLocation"]["Longitude"])
print Longitude
# Out:
# -74.036371

# %%
Latitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"])
print Latitude
# Out:
# 40.63684

# %%
Latitude = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][1]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"])
print Latitude
# Out:
# 40.623271

# %%
print "Bus Line : %s" %  (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
# Out:
# Bus Line : B9

# %%
#https://www.tutorialspoint.com/python/dictionary_len.htm
BusNumbers = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"])
print "Number of Active Buses : %d" % len (BusNumbers)
# Out:
# Number of Active Buses : 16

# %%
BusNum = len (BusNumbers)
print BusNum
# Out:
# 16

# %%
for i in range(BusNum):
    print (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"])
# Out:
# {u'Latitude': 40.63684, u'Longitude': -74.036371}
# {u'Latitude': 40.623271, u'Longitude': -73.989355}
# {u'Latitude': 40.617125, u'Longitude': -73.967891}
# {u'Latitude': 40.620764, u'Longitude': -73.985183}
# {u'Latitude': 40.621752, u'Longitude': -73.947986}
# {u'Latitude': 40.634803, u'Longitude': -74.023949}
# {u'Latitude': 40.634749, u'Longitude': -74.023463}
# {u'Latitude': 40.640518, u'Longitude': -74.017906}
# {u'Latitude': 40.620985, u'Longitude': -73.954888}
# {u'Latitude': 40.622793, u'Longitude': -73.938494}
# {u'Latitude': 40.617865, u'Longitude': -73.961106}
# {u'Latitude': 40.624088, u'Longitude': -73.9907}
# {u'Latitude': 40.622845, u'Longitude': -73.938051}
# {u'Latitude': 40.609052, u'Longitude': -73.921488}
# {u'Latitude': 40.608624, u'Longitude': -73.921012}
# {u'Latitude': 40.608491, u'Longitude': -73.920863}

# %%
A = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]
A
# Out:
# {u'Latitude': 40.608491, u'Longitude': -73.920863}

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?" + "&key=7f84d332-2f33-49c1-94f5-fdc4cf2231ae" + "&OperatorRef=MTA&VehicleMonitoringDetailLevel=calls&LineRef=MTA%20NYCT_B15" 
response = urllib.urlopen(url)
a = pd.read_json(url)
data = response.read().decode("utf-8")
parsed_data = json.loads(data)
print "Bus Line : %s" %  (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"][0]["MonitoredVehicleJourney"]["PublishedLineName"])
BusNumbers = (parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]
      ["VehicleActivity"])
print "Number of Active Buses : %d" % len (BusNumbers)
BusNum = len (BusNumbers)
for i in range(BusNum):
    B = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]["Latitude"]
    C = parsed_data["Siri"]["ServiceDelivery"]["VehicleMonitoringDelivery"][0]["VehicleActivity"][i]["MonitoredVehicleJourney"]["VehicleLocation"]["Longitude"]
    print ("Bus %s" % i + " is at Latitude %s" % B + " Longitude %s" % C )
# Out:
# Bus Line : B15
# Number of Active Buses : 23
# Bus 0 is at Latitude 40.647204 Longitude -73.779707
# Bus 1 is at Latitude 40.669535 Longitude -73.863389
# Bus 2 is at Latitude 40.665 Longitude -73.88584
# Bus 3 is at Latitude 40.696986 Longitude -73.937865
# Bus 4 is at Latitude 40.669285 Longitude -73.874019
# Bus 5 is at Latitude 40.659003 Longitude -73.899418
# Bus 6 is at Latitude 40.656306 Longitude -73.907008
# Bus 7 is at Latitude 40.68338 Longitude -73.938115
# Bus 8 is at Latitude 40.669391 Longitude -73.860876
# Bus 9 is at Latitude 40.67014 Longitude -73.922788
# Bus 10 is at Latitude 40.676253 Longitude -73.938623
# Bus 11 is at Latitude 40.675297 Longitude -73.93548
# Bus 12 is at Latitude 40.665226 Longitude -73.885317
# Bus 13 is at Latitude 40.658459 Longitude -73.900688
# Bus 14 is at Latitude 40.676519 Longitude -73.938742
# Bus 15 is at Latitude 40.696263 Longitude -73.937702
# Bus 16 is at Latitude 40.653562 Longitude -73.807334
# ...

# %%
# 7f84d332-2f33-49c1-94f5-fdc4cf2231ae

# %%
# When the OnwardCalls field is empty, you must output “N/A” as values for both the “Stop Name” and “Stop Status” fields.
